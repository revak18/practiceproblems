# %% [markdown]
# <a href="https://colab.research.google.com/github/revak18/practiceproblems/blob/main/FTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import ee
import pandas as pd

ee.Initialize()
# Out:
# ---------------------------------------------------------------------------
# TransportError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/credentials.py in refresh(self, request)
#     127         try:
# --> 128             self._retrieve_info(request)
#     129             self.token, self.expiry = _metadata.get_service_account_token(
#
# /usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/credentials.py in _retrieve_info(self, request)
#     100         """
# --> 101         info = _metadata.get_service_account_info(
#     102             request, service_account=self._service_account_email
#
# /usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/_metadata.py in get_service_account_info(request, service_account)
#     322     # for more on the use of 'recursive'.
# --> 323     return get(request, path, params={"recursive": "true"})
#     324
#
# ...

# %%
import ee
import pandas as pd

ee.Initialize()


FTM_trees = pd.read_csv('/content/drive/MyDrive/FTM Science Fair Data/FTM_TREES.csv')

FTM_fires = pd.read_csv('/content/drive/MyDrive/FTM Science Fair Data/FTM_FIRES.csv')

def get_pdsi_collection(yr):
  fire_yr = ee.Date(pd.to_datetime(yr))
  ## -1 indicate previous year data and 3 indicates 3 years starting from year of Fire
  ## For example for Fire that happened in 2001, below statement would fetch data for 2000, 2001, 2002 & 2003
  date_range = ee.DateRange(fire_yr.advance(-1, 'years'), fire_yr.advance(3, 'years'))
  pdsi = ee.ImageCollection('GRIDMET/DROUGHT').filterDate(date_range).select('pdsi')
  return pdsi
# Out:
# ---------------------------------------------------------------------------
# TransportError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/credentials.py in refresh(self, request)
#     127         try:
# --> 128             self._retrieve_info(request)
#     129             self.token, self.expiry = _metadata.get_service_account_token(
#
# /usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/credentials.py in _retrieve_info(self, request)
#     100         """
# --> 101         info = _metadata.get_service_account_info(
#     102             request, service_account=self._service_account_email
#
# /usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/_metadata.py in get_service_account_info(request, service_account)
#     322     # for more on the use of 'recursive'.
# --> 323     return get(request, path, params={"recursive": "true"})
#     324
#
# ...

# %%
FTM_fires.head()
# Out:
#                     YrFireName                  Fire Dataset    N  yr_fire  \
# 0         1981 - Manning Basin         Manning Basin   Brown  465     1981
# 1             1981 - Snowdrift             Snowdrift   Brown  481     1981
# 2           1981 - Steep Creek           Steep Creek   Brown  323     1981
# 3  1982 - SEKI 69 or 74 Reburn  SEKI 69 or 74 Reburn     NPS    9     1982
# 4                  1983 - Oops                  Oops    Hood  170     1983
#
#     Latitude   Longitude  Elevation  month_fire  day_fire Fire_type  \
# 0  42.602739 -111.119003       2028         9.0      22.0        RX
# 1  42.549037 -111.226913       2860         9.0      22.0        RX
# 2  42.272226 -110.556666       2368         9.0      28.0      Wild
# 3  36.706663 -118.920540       1903         NaN       NaN       NaN
# 4  48.359752 -116.752536       1303        10.0       NaN      Wild
#
#         State    Sample_design   Plot_size_ha   Threshold_diameter_cm  \
# ...

# %%
get_pdsi_collection(1983)
# Out:
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# <ipython-input-19-5dca6c7227c1> in <cell line: 1>()
# ----> 1 get_pdsi_collection(1983)
#
# <ipython-input-18-09d57a10f3d4> in get_pdsi_collection(yr)
#      10
#      11 def get_pdsi_collection(yr):
# ---> 12   fire_yr = ee.Date(pd.to_datetime(yr))
#      13   ## -1 indicate previous year data and 3 indicates 3 years starting from year of Fire
#      14   ## For example for Fire that happened in 2001, below statement would fetch data for 2000, 2001, 2002 & 2003
#
# /usr/local/lib/python3.10/dist-packages/ee/computedobject.py in __call__(cls, *args, **kwargs)
#      26       return args[0]
#      27     else:
# ---> 28       return type.__call__(cls, *args, **kwargs)
#      29
#      30
#
# /usr/local/lib/python3.10/dist-packages/ee/_utils.py in wrapper(*args, **kwargs)
#      36           if new_key not in kwargs:
# ...
