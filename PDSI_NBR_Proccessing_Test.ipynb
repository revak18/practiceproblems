# %% [markdown]
# <a href="https://colab.research.google.com/github/revak18/practiceproblems/blob/main/PDSI_NBR_Proccessing_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import glob
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os # operating system
import pandas as pd
file_path = '/content/drive/MyDrive/Science_Fair/ScienceFairProject2024/PDSI_FINAL/'

filelist=[]


for file in os.listdir(file_path):
  if file.startswith('1_PDSI_'):
    filelist.append(file)

print(len(filelist))

df = pd.DataFrame()
FTM_PDSI = []
dfs = []

for i in filelist:
  str = file_path+i
  print("file: ", str)
  df = pd.read_csv(str)
  dfs.append(df)



FTM_PDSI = pd.concat(dfs, ignore_index=True)
FTM_PDSI.head()
# Out:
# 2688
# file:  /content/drive/MyDrive/Science_Fair/ScienceFairProject2024/PDSI_FINAL/1_PDSI_6_2000 - BRCA Puma.csv
# file:  /content/drive/MyDrive/Science_Fair/ScienceFairProject2024/PDSI_FINAL/1_PDSI_5_2002 - Borrego.csv
# file:  /content/drive/MyDrive/Science_Fair/ScienceFairProject2024/PDSI_FINAL/1_PDSI_3_2005 - Harding.csv
# file:  /content/drive/MyDrive/Science_Fair/ScienceFairProject2024/PDSI_FINAL/1_PDSI_4_2001 - Rogers Shack.csv
# file:  /content/drive/MyDrive/Science_Fair/ScienceFairProject2024/PDSI_FINAL/1_PDSI_5_2001 - FSS6.csv
# file:  /content/drive/MyDrive/Science_Fair/ScienceFairProject2024/PDSI_FINAL/1_PDSI_5_2000 - BRCA Puma.csv
# file:  /content/drive/MyDrive/Science_Fair/ScienceFairProject2024/PDSI_FINAL/1_PDSI_4_2014 - San Juan.csv
# file:  /content/drive/MyDrive/Science_Fair/ScienceFairProject2024/PDSI_FINAL/1_PDSI_7_2011 - Lutz.csv
# file:  /content/drive/MyDrive/Science_Fair/ScienceFairProject2024/PDSI_FINAL/1_PDSI_5_2008 - New Fork.csv
# ...
